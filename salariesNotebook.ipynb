# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_salary = pd.read_csv(r"C:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\ds_salaries_edit.csv")
df_salary.head()
# Out:
#    work_year experience_level employment_type                 job_title
# 0       2023               SE              FT  Principal Data Scientist  \
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio
# 0   80000             EUR          85847                 ES           100  \
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size  experience_level_numeric
# ...

# %%
# checking for null values
pd.isnull(df_salary).sum()
# Out:
# work_year                   0
# experience_level            0
# employment_type             0
# job_title                   0
# salary                      0
# salary_currency             0
# salary_in_usd               0
# employee_residence          0
# remote_ratio                0
# company_location            0
# company_size                0
# experience_level_numeric    0
# dtype: int64

# %%
# identify the total # of rows and columns in the data set

df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   work_year                 3755 non-null   int64
#  1   experience_level          3755 non-null   object
#  2   employment_type           3755 non-null   object
#  3   job_title                 3755 non-null   object
#  4   salary                    3755 non-null   int64
#  5   salary_currency           3755 non-null   object
#  6   salary_in_usd             3755 non-null   int64
#  7   employee_residence        3755 non-null   object
#  8   remote_ratio              3755 non-null   int64
#  9   company_location          3755 non-null   object
#  10  company_size              3755 non-null   object
#  11  experience_level_numeric  3755 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 352.2+ KB

# %%
df_salary.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_salary.corr()
#
# File c:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\.conda\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\.conda\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
#checking the data types of each column to find the ones that have non numeric values based on the above error
df_salary.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# changing the experience_level to a numerical value instead of string
mapping = {'SE': 3, 'MI': 2, 'EN':1}
df_salary['experience_level'] = df_salary['experience_level'].replace(mapping)

# %%
#checking to see if the above worked
df_salary.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# did not work, because experience level still shows up as an object and i need it to be an int64, checking to see what is says now
df_salary.head(10)
# Out:
#    work_year experience_level employment_type                 job_title
# 0       2023                3              FT  Principal Data Scientist  \
# 1       2023                2              CT               ML Engineer
# 2       2023                2              CT               ML Engineer
# 3       2023                3              FT            Data Scientist
# 4       2023                3              FT            Data Scientist
# 5       2023                3              FT         Applied Scientist
# 6       2023                3              FT         Applied Scientist
# 7       2023                3              FT            Data Scientist
# 8       2023                3              FT            Data Scientist
# 9       2023                3              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio
# 0   80000             EUR          85847                 ES           100  \
# ...

# %%
# trying to see if it will work anyway
df_salary.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # trying to see if it will work anyway
# ----> 2 df_salary.corr()
#
# File c:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\.conda\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\.conda\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
# Reversing the mapping done
mapping = {3: 'SE', 2: 'MI', 1:'EN'}
df_salary['experience_level'] = df_salary['experience_level'].replace(mapping)

# %%
# Define the mapping dictionary for experience levels
mapping = {'EX': 4, 'SE': 3, 'MI': 2, 'EN': 1}

# Create a new column 'Experience Numeric' with the numerical values
df_salary['experience_level_numeric'] = df_salary['experience_level'].replace(mapping)

# Save the modified DataFrame back to the Excel file
df_salary.to_csv(r'C:\Users\sophomore\Documents\GitHub\dataScienceSalariesAnalysis\ds_salaries_edit.csv', index=False)

# %%
df_salary.head(100)
# Out:
#     work_year experience_level employment_type                  job_title
# 0        2023               SE              FT   Principal Data Scientist  \
# 1        2023               MI              CT                ML Engineer
# 2        2023               MI              CT                ML Engineer
# 3        2023               SE              FT             Data Scientist
# 4        2023               SE              FT             Data Scientist
# ..        ...              ...             ...                        ...
# 95       2023               EN              FT  Machine Learning Engineer
# 96       2023               EN              FT  Machine Learning Engineer
# 97       2023               SE              FT              Data Engineer
# 98       2023               SE              FT              Data Engineer
# 99       2023               SE              FT               Data Analyst
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio
# ...

# %%
#checking correlation between two columns
correlation = df_salary['experience_level_numeric'].corr(df_salary['salary_in_usd'])
print("Correlation: ", correlation)
# Out:
# Correlation:  0.4416681936012786

# %%
# Plotting the correlation
import matplotlib.pyplot as plt
plt.scatter(df_salary['experience_level'], df_salary['salary_in_usd'])
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.title('Scatter plot of Experience Level vs. Salary in USD')
#tick_interval = 0.2
#tick_positions = [i * tick_interval for i in range(int(df_salary['salary_in_usd'].max() / tick_interval) + 1)]
#plt.yticks(tick_positions)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df_salary['experience_level_numeric'], df_salary['salary_in_usd'])
plt.xlabel('Experience Level')
plt.ylabel('Salary')
plt.title('Scatter plot of Experience Level vs. Salary in USD')
#tick_interval = 0.2
#tick_positions = [i * tick_interval for i in range(int(df_salary['salary_in_usd'].max() / tick_interval) + 1)]
#plt.yticks(tick_positions)
plt.show()

# %%
# %pip install scipy
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(df_salary['experience_level_numeric'], df_salary['salary_in_usd'])

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, df_salary['experience_level_numeric'] ))

plt.scatter(df_salary['experience_level_numeric'], df_salary['salary_in_usd'])
plt.plot(df_salary['experience_level_numeric'], mymodel)
plt.title('Linear Regression of Experience Level vs. Salary in USD')
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
specific_jobs = ['Data Scientist', 'Data Engineer', 'Data Analyst', 'Research Engineer', 'Machine Learning Engineer', 'Data Analytics Manager', 'Data Specialist']

df_filtered_jobs = df_salary[df_salary['job_title'].isin(specific_jobs)]
#allows for only specific jobs to show up
average_salary = df_filtered_jobs.groupby('job_title')['salary_in_usd'].mean()

plt.figure(figsize=(16,8))
average_salary.plot(kind='bar')
plt.xlabel('Job Title')
plt.ylabel('Average salary USD')
plt.title('Average salary in USD by role')
plt.xticks(rotation=45)

plt.show()

# %%
#finding standard deviation

all_salaries_std = df_salary["salary_in_usd"].std()
print("Standard Deviation of all saleries: ", all_salaries_std)
# Out:
# Standard Deviation of all saleries:  63055.6252782241

# %%
import statistics
